# %% [markdown]
# <a href="https://colab.research.google.com/github/Gishnurahul/Analytricks/blob/main/Wine_Quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
sns.set_style("darkgrid")
sns.set(font_scale=1.5)

# Read in dataset
url = 'https://raw.githubusercontent.com/Gishnurahul/Analytricks/main/winequality-red.csv'

df= pd.read_csv(url)
#df = pd.read_csv(url,index_col=0)
#df = pd.read_csv('/content/winequality-red.csv')
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.figure(figsize=(14,8)) # set thaciditye size of the graph
_ = sns.regplot(data=df, x='volatile acidity', y='quality', color='blue')

# %%
plt.figure(figsize=(14,8)) # set the size of the graph
_ = sns.regplot(data=df, x='alcohol', y='quality', color='black')

# %%
sns.pairplot(df, hue="quality", palette="RdBu")

# %%
# create tabular correlation matrix
corr = df.corr()
_, ax = plt.subplots(figsize=(20,10)) 

# graph correlation matrix
_ = sns.heatmap(corr, ax=ax,
                xticklabels=corr.columns.values,
                yticklabels=corr.columns.values,
                cmap='RdBu',annot=True)

# %%
from sklearn.model_selection import train_test_split
#from sklearn.datasets import load_iris
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.02)

# %%
from sklearn import linear_model
X = df[['fixed acidity','volatile acidity','citric acid', 'residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol', ]] # here we have all variables for multiple regression.
Y = df['quality']  # Dependant variable.
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)
regr.score(x_test,y_test)
# Out:
# 0.35001978843614423

# %%
model= LinearRegression().fit(x_train,y_train)
predictions=model.predict(x_test)
import matplotlib.pyplot as plt
plt.scatter(y_test,predictions)

# %%
regr.score(x_test,y_test)
# Out:
# 0.4390133655629477

# %%
from sklearn.linear_model import LinearRegression 
Vo_Alc = df[['volatile acidity','alcohol', ]] # here we have 2 major independant factors
Q = df['quality']  # Dependant variable.
# with sklearn
selectregr = linear_model.LinearRegression()
selectregr.fit(Vo_Alc, Q)
selectregr.score(Vo_Alc, Q)
# Out:
# 0.31700243279698515

# %%
#predict the quality where the Volatile acidity is 0.3 g/L and Alcohol% is 20%:
predictedquality = selectregr.predict([[0.3, 20]])

print(predictedquality)
# Out:
# [8.95663087]
